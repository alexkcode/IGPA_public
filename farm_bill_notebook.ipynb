# %% [markdown]
# ## Imports and Utility Functions

# %%
import pandas as pd
import numpy as np
import requests, urllib, os, re
from datetime import date
import tabula
from dotenv import load_dotenv
from urllib.parse import urljoin, unquote
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support.ui import WebDriverWait

import sqlalchemy
from sqlalchemy import Table, create_engine

load_dotenv(dotenv_path='./.env')

POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')

def get_page_source(url):
    options = Options()
    options.headless = True
    driver = webdriver.Firefox(options=options)
    driver.get(url)
    WebDriverWait(driver, 5)
    # logger.debug("Headless Firefox Initialized")

    source = driver.page_source
    driver.quit()
    return source

def parse_urls(source, ext='xlsx'):
    selector = BeautifulSoup(source, 'html.parser')
    selection = selector.select('a[href$="{}"]'.format(ext))
    arr = []
    for item in selection:
        file_url = 'https://www.fsa.usda.gov/' + item['href']
        # print('Got URL ' + str(file_url))
        if ext in file_url:
            arr.append(file_url)
    return arr
    
def download(url:str, destination:str):
    dl_path = os.getcwd().replace('\\', '/') + '/data/' + destination + '/'
    fn = unquote(url.split('/')[-1])
    full_path = dl_path + fn
    response = requests.get(url)
    print('Response: ', response)

    # self.logger.debug('Response: ', response)

    if not os.path.exists(dl_path):
        os.makedirs(dl_path)
    if os.path.exists(full_path):
        return full_path

    # self.logger.info('Filename: ' + fn)
    # self.logger.info('File path: ' + download_path)
    f = open(full_path, 'wb')
    f.write(response.content)
    f.close()
    print(fn, 'downloaded to ', full_path)
    return full_path

def listdirs(rootdir):
    # rootdir = rootdir.replace('\\', '/')
    for path, subdirs, files in os.walk(rootdir):
        for file in files:
            # yield file
            yield os.path.join(path, file)

def to_snake_case(name):
    # name = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    name = name.replace(' ', '_')
    name = re.sub('__([A-Z])', r'_\1', name)
    # name = re.sub('([a-z0-9])([A-Z])', r'\1_\2', name)
    return name.lower()

def to_sql_type(t):
    dict={
        'int': 'INTEGER',
        'float': 'FLOAT',
        'datetime': 'DATETIME'
    }
    for key in dict:
        if key in t.lower():
            return dict.get(key)
    return 'VARCHAR'

def to_sqlalchemy_type(t):
    dict={
        'int': sqlalchemy.types.Integer,
        'float': sqlalchemy.types.Float,
        'datetime': sqlalchemy.types.DateTime
    }
    for key in dict:
        if key in t.lower():
            return dict.get(key)
    return sqlalchemy.types.String

def alter_table(table, col, col_type, engine: sqlalchemy.engine):
    sql = """
    alter table {table}
    add column "{col}" {type}
    default NULL;
    """.format(table=table, col=col, type=to_sql_type(col_type))
    print(sql)
    try:
        with engine.connect() as connection:
            with connection.begin():
                result = connection.execute(sql)
    except Exception as e:
        if 'already exists' in str(e):
            # LOGGER.error(e)
            print(e)
        else:
            raise e
    print('Added column {0} to table {1}.'.format(col, table))

def fix_columns(table_name, df_1, df_2, engine: sqlalchemy.engine):
    unionized_cols = df_1.columns.union(df_2.columns)
    diff_cols = df_2.columns.difference(df_1.columns)
    print('Column differences: {0}'.format(diff_cols))
    for col, t in zip(df_2.columns, df_2.dtypes):
        if col in diff_cols:
            t = str(t)
            alter_table(table_name, col, t, engine)
            
def find_file(target):
    file_list = []
    for path, subdirs, files in os.walk(os.path.expanduser("~")):
        path = path.replace("\\", "/")
        for file in files:
            regex = re.compile(target)
            if regex.search(path + "/" + file):
                file_list.append(path + "/" + file)
    return file_list

# %%
engine = sqlalchemy.create_engine('postgresql://admin:{password}@localhost:15432/usda'.format(password=POSTGRES_PASSWORD))

crp_file_list = find_file('.*conservation_summaries.*pdf')

crp_file_list
# Out:
# []

# %% [markdown]
# ## Download payment files

# %%
url = 'https://www.fsa.usda.gov/news-room/efoia/electronic-reading-room/frequently-requested-information/payment-files-information/index'
urls = parse_urls(get_page_source(url))
download_paths = []

engine = create_engine('postgresql+psycopg2://user:password\@hostname/database_name', echo=False)

for url in urls:
    download_paths.append(download(url, 'raw/payment_files'))
# Out:
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_al-in_na_pmt21_final_dt22004.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_ia-mi_na_pmt21_final_dt22004.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_mn-nc_na_pmt21_final_dt22004.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_nd-tn_na_pmt21_final_dt22004.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_tx-wy_na_pmt21_final_dt22004.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-al-id_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-ia_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-il_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-in_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-ks-mi_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-mn-mo_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-mt-nd_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-oh-sd_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-tn-wv_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2020/state-wi-wy_na_pmt20_final_dt21008.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2019/state-al-in_na_pmt19_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2019/state-ia-mi_na_pmt19_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2019/state-mn-nc_na_pmt19_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2019/state-nd-tn_na_pmt19_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2019/state-tx-wy_na_pmt19_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2018/state-al-in_na_pmt18_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2018/state-ia-mn_na_pmt18_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2018/state-ms-oh_na_pmt18_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2018/state-ok-wy_na_pmt18_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2017/state-al-in_na_pmt17_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2017/state-ia-ms_na_pmt17_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2017/state-mo-sc_na_pmt17_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2017/state-sd-wy_na_pmt17_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2016/state-al-in_na_pmt16_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2016/state-ia-mn_na_pmt16_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2016/state-ms-oh_na_pmt16_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2016/state-ok-wy_na_pmt16_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2015/state-al-ia_na_pmt15_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2015/state-ks-nd_na_pmt15_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2015/state-oh-wy_na_pmt15_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2014/state-al-mt_na_pmt14_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2014/state-ne-wy_na_pmt14_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2013/state-al-in_na_pmt13_final_dt21070.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2013/state-ia-mi_na_pmt13_final_dt21070.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2013/state-mn-nd_na_pmt13_final_dt21070.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2013/state-oh-wv_na_pmt13_final_dt21070.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2013/state-wi-wy_na_pmt13_final_dt21070.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2012/state-al-in_na_pmt12_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2012/state-ia-mi_na_pmt12_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2012/state-mn-nd_na_pmt12_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2012/state-oh-wv_na_pmt12_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2012/state-wi-wy_na_pmt12_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_al-id_na_pmt11_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_ia-ks_na_pmt11_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_il-in_na_pmt11_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_ky-mo_na_pmt11_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_mt-oh_na_pmt11_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_ok-wa_na_pmt11_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/excel/state_wv-wy_na_pmt11_final_dt20297.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-al-id_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-ia-ks_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-il-in_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-ky-ms_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-mo-nc_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-nd-sc_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-sd-va_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2010/state-wa-wy_na_pmt10_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2009/state-al-il_na_pmt09_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2009/state-in-ks_na_pmt09_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2009/state-ky-mo_na_pmt09_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2009/state-mt-or_na_pmt09_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2009/state-pa-wv_na_pmt09_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2009/state-wi-wy_na_pmt09_final_dt11186.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-al-fl_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-ga-id_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-ia_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-il-001-099_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-il-101-203_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-in_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-ks_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-ky-mi_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-mn-ms_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-mo-mt_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-nc-nd_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-ne-ny_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-oh-ri_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-sc-tn_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-tx-va_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2008/state-wa-wy_na_pmt08_final_dt10189.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2004-2007/state-al-wy_na_pmt07_final_dt21048.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2004-2007/state-al-wy_na_pmt06_final_dt21048.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2004-2007/state-al-wy_na_pmt05_final_dt21048.xlsx
# Working on https://www.fsa.usda.gov//Assets/USDA-FSA-Public/usdafiles/NewsRoom/eFOIA/payment-files/excel/2004-2007/state-ca-wi_na_pmt04_final_dt21048.xlsx
# Response:  <Response [200]>
# state_al-in_na_pmt21_final_dt22004.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_al-in_na_pmt21_final_dt22004.xlsx
# Response:  <Response [200]>
# state_ia-mi_na_pmt21_final_dt22004.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_ia-mi_na_pmt21_final_dt22004.xlsx
# Response:  <Response [200]>
# state_mn-nc_na_pmt21_final_dt22004.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_mn-nc_na_pmt21_final_dt22004.xlsx
# Response:  <Response [200]>
# state_nd-tn_na_pmt21_final_dt22004.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_nd-tn_na_pmt21_final_dt22004.xlsx
# Response:  <Response [200]>
# state_tx-wy_na_pmt21_final_dt22004.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_tx-wy_na_pmt21_final_dt22004.xlsx
# Response:  <Response [200]>
# state-al-id_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-id_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-ia_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-il_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-il_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-in_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-in_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-ks-mi_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ks-mi_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-mn-mo_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mn-mo_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-mt-nd_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mt-nd_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-oh-sd_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-oh-sd_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-tn-wv_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-tn-wv_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-wi-wy_na_pmt20_final_dt21008.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-wi-wy_na_pmt20_final_dt21008.xlsx
# Response:  <Response [200]>
# state-al-in_na_pmt19_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-in_na_pmt19_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ia-mi_na_pmt19_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia-mi_na_pmt19_final_dt20297.xlsx
# Response:  <Response [200]>
# state-mn-nc_na_pmt19_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mn-nc_na_pmt19_final_dt20297.xlsx
# Response:  <Response [200]>
# state-nd-tn_na_pmt19_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-nd-tn_na_pmt19_final_dt20297.xlsx
# Response:  <Response [200]>
# state-tx-wy_na_pmt19_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-tx-wy_na_pmt19_final_dt20297.xlsx
# Response:  <Response [200]>
# state-al-in_na_pmt18_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-in_na_pmt18_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ia-mn_na_pmt18_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia-mn_na_pmt18_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ms-oh_na_pmt18_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ms-oh_na_pmt18_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ok-wy_na_pmt18_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ok-wy_na_pmt18_final_dt20297.xlsx
# Response:  <Response [200]>
# state-al-in_na_pmt17_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-in_na_pmt17_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ia-ms_na_pmt17_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia-ms_na_pmt17_final_dt20297.xlsx
# Response:  <Response [200]>
# state-mo-sc_na_pmt17_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mo-sc_na_pmt17_final_dt20297.xlsx
# Response:  <Response [200]>
# state-sd-wy_na_pmt17_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-sd-wy_na_pmt17_final_dt20297.xlsx
# Response:  <Response [200]>
# state-al-in_na_pmt16_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-in_na_pmt16_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ia-mn_na_pmt16_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia-mn_na_pmt16_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ms-oh_na_pmt16_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ms-oh_na_pmt16_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ok-wy_na_pmt16_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ok-wy_na_pmt16_final_dt20297.xlsx
# Response:  <Response [200]>
# state-al-ia_na_pmt15_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-ia_na_pmt15_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ks-nd_na_pmt15_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ks-nd_na_pmt15_final_dt20297.xlsx
# Response:  <Response [200]>
# state-oh-wy_na_pmt15_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-oh-wy_na_pmt15_final_dt20297.xlsx
# Response:  <Response [200]>
# state-al-mt_na_pmt14_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-mt_na_pmt14_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ne-wy_na_pmt14_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ne-wy_na_pmt14_final_dt20297.xlsx
# Response:  <Response [200]>
# state-al-in_na_pmt13_final_dt21070.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-in_na_pmt13_final_dt21070.xlsx
# Response:  <Response [200]>
# state-ia-mi_na_pmt13_final_dt21070.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia-mi_na_pmt13_final_dt21070.xlsx
# Response:  <Response [200]>
# state-mn-nd_na_pmt13_final_dt21070.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mn-nd_na_pmt13_final_dt21070.xlsx
# Response:  <Response [200]>
# state-oh-wv_na_pmt13_final_dt21070.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-oh-wv_na_pmt13_final_dt21070.xlsx
# Response:  <Response [200]>
# state-wi-wy_na_pmt13_final_dt21070.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-wi-wy_na_pmt13_final_dt21070.xlsx
# Response:  <Response [200]>
# state-al-in_na_pmt12_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-in_na_pmt12_final_dt20297.xlsx
# Response:  <Response [200]>
# state-ia-mi_na_pmt12_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia-mi_na_pmt12_final_dt20297.xlsx
# Response:  <Response [200]>
# state-mn-nd_na_pmt12_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mn-nd_na_pmt12_final_dt20297.xlsx
# Response:  <Response [200]>
# state-oh-wv_na_pmt12_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-oh-wv_na_pmt12_final_dt20297.xlsx
# Response:  <Response [200]>
# state-wi-wy_na_pmt12_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-wi-wy_na_pmt12_final_dt20297.xlsx
# Response:  <Response [200]>
# state_al-id_na_pmt11_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_al-id_na_pmt11_final_dt20297.xlsx
# Response:  <Response [200]>
# state_ia-ks_na_pmt11_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_ia-ks_na_pmt11_final_dt20297.xlsx
# Response:  <Response [200]>
# state_il-in_na_pmt11_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_il-in_na_pmt11_final_dt20297.xlsx
# Response:  <Response [200]>
# state_ky-mo_na_pmt11_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_ky-mo_na_pmt11_final_dt20297.xlsx
# Response:  <Response [200]>
# state_mt-oh_na_pmt11_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_mt-oh_na_pmt11_final_dt20297.xlsx
# Response:  <Response [200]>
# state_ok-wa_na_pmt11_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_ok-wa_na_pmt11_final_dt20297.xlsx
# Response:  <Response [200]>
# state_wv-wy_na_pmt11_final_dt20297.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state_wv-wy_na_pmt11_final_dt20297.xlsx
# Response:  <Response [200]>
# state-al-id_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-id_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-ia-ks_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia-ks_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-il-in_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-il-in_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-ky-ms_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ky-ms_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-mo-nc_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mo-nc_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-nd-sc_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-nd-sc_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-sd-va_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-sd-va_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-wa-wy_na_pmt10_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-wa-wy_na_pmt10_final_dt11186.xlsx
# Response:  <Response [200]>
# state-al-il_na_pmt09_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-il_na_pmt09_final_dt11186.xlsx
# Response:  <Response [200]>
# state-in-ks_na_pmt09_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-in-ks_na_pmt09_final_dt11186.xlsx
# Response:  <Response [200]>
# state-ky-mo_na_pmt09_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ky-mo_na_pmt09_final_dt11186.xlsx
# Response:  <Response [200]>
# state-mt-or_na_pmt09_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mt-or_na_pmt09_final_dt11186.xlsx
# Response:  <Response [200]>
# state-pa-wv_na_pmt09_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-pa-wv_na_pmt09_final_dt11186.xlsx
# Response:  <Response [200]>
# state-wi-wy_na_pmt09_final_dt11186.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-wi-wy_na_pmt09_final_dt11186.xlsx
# Response:  <Response [200]>
# state-al-fl_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-fl_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-ga-id_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ga-id_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-ia_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ia_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-il-001-099_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-il-001-099_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-il-101-203_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-il-101-203_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-in_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-in_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-ks_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ks_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-ky-mi_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ky-mi_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-mn-ms_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mn-ms_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-mo-mt_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-mo-mt_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-nc-nd_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-nc-nd_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-ne-ny_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ne-ny_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-oh-ri_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-oh-ri_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-sc-tn_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-sc-tn_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-tx-va_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-tx-va_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-wa-wy_na_pmt08_final_dt10189.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-wa-wy_na_pmt08_final_dt10189.xlsx
# Response:  <Response [200]>
# state-al-wy_na_pmt07_final_dt21048.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-wy_na_pmt07_final_dt21048.xlsx
# Response:  <Response [200]>
# state-al-wy_na_pmt06_final_dt21048.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-wy_na_pmt06_final_dt21048.xlsx
# Response:  <Response [200]>
# state-al-wy_na_pmt05_final_dt21048.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-al-wy_na_pmt05_final_dt21048.xlsx
# Response:  <Response [200]>
# state-ca-wi_na_pmt04_final_dt21048.xlsx downloaded to  c:/Users/kwan1/Documents/GitHub/IGPA/data/raw/payment_files/state-ca-wi_na_pmt04_final_dt21048.xlsx

# %% [markdown]
# ## Download Monthly Conservation Reserve Program Summaries

# %%
url = 'https://www.fsa.usda.gov/programs-and-services/conservation-programs/reports-and-statistics/conservation-reserve-program-statistics/index'
urls = parse_urls(get_page_source(url), ext='pdf')
download_paths = []

for url in urls:
    if 'summary' in url.lower():
        # print(url)
        download_paths.append(download(url, 'raw/conservation_summaries'))
# Out:
# Response:  <Response [200]>
# Summary January 2023 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2023 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary December 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary November 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary Octoberr 2022 CRPMonthly-1.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary Octoberr 2022 CRPMonthly-1.pdf
# Response:  <Response [200]>
# Summary September 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary August 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary JULY 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# June 2022 Summary CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2022 Summary CRPMonthly.pdf
# Response:  <Response [200]>
# Summary May 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary May 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary April 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary February 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary January 2022 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2022 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary December 2021 CRP Monthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2021 CRP Monthly.pdf
# Response:  <Response [200]>
# Summary November 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary October 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary October 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary September 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary August 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary JULY 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary JUNE 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary April 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary March 2021-1.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary March 2021-1.pdf
# Response:  <Response [200]>
# Summary February 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary January 2021 CRPMonthly.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2021 CRPMonthly.pdf
# Response:  <Response [200]>
# Summary December 2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2020.pdf
# Response:  <Response [200]>
# crp-summary-nov-2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-nov-2020.pdf
# Response:  <Response [200]>
# crp-summary-oct-2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-oct-2020.pdf
# Response:  <Response [200]>
# Summary-September-2020-1.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary-September-2020-1.pdf
# Response:  <Response [200]>
# Summary AUG 2020-1.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2020-1.pdf
# Response:  <Response [200]>
# Summary JUL 2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2020.pdf
# Response:  <Response [200]>
# Summary JUNE 2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2020.pdf
# Response:  <Response [200]>
# Summary MAY 2020-2.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAY 2020-2.pdf
# Response:  <Response [200]>
# Summary APR2020 (002).pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary APR2020 (002).pdf
# Response:  <Response [200]>
# Summary MAR 2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAR 2020.pdf
# Response:  <Response [200]>
# Summary FEB 2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary FEB 2020.pdf
# Response:  <Response [200]>
# Summary JAN 2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JAN 2020.pdf
# Response:  <Response [200]>
# DEC 2019 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/DEC 2019 Summary.pdf
# Response:  <Response [200]>
# NOV 2019 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/NOV 2019 Summary.pdf
# Response:  <Response [200]>
# OCT 2019 Summary2.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT 2019 Summary2.pdf
# Response:  <Response [200]>
# Sep 2019 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Sep 2019 Summary.pdf
# Response:  <Response [200]>
# Summary AUG 2019-1.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2019-1.pdf
# Response:  <Response [200]>
# Summary JUL 2019-1.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2019-1.pdf
# Response:  <Response [200]>
# Summary JUN 2019.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUN 2019.pdf
# Response:  <Response [200]>
# Summary 2019 MAY.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 MAY.pdf
# Response:  <Response [200]>
# Summary April 2019.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2019.pdf
# Response:  <Response [200]>
# Summary 2019 March.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 March.pdf
# Response:  <Response [200]>
# Summary February 2019.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2019.pdf
# Response:  <Response [200]>
# January 2019 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/January 2019 Summary.pdf
# Response:  <Response [200]>
# December 2018 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/December 2018 Summary.pdf
# Response:  <Response [200]>
# November 2018 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/November 2018 Summary.pdf
# Response:  <Response [200]>
# OCT2018 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT2018 Summary.pdf
# Response:  <Response [200]>
# SEP2018 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/SEP2018 Summary.pdf
# Response:  <Response [200]>
# JULY 2018 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/JULY 2018 Summary.pdf
# Response:  <Response [200]>
# June 2018 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2018 Summary.pdf
# Response:  <Response [200]>
# MAY 2018 Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/MAY 2018 Summary.pdf
# Response:  <Response [200]>
# September2017Summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/September2017Summary.pdf
# Response:  <Response [200]>
# sep2015summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2015summary.pdf
# Response:  <Response [200]>
# summarysept2014.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summarysept2014.pdf
# Response:  <Response [200]>
# sep2013summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2013summary.pdf
# Response:  <Response [200]>
# Annual Summary 2020.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Annual Summary 2020.pdf
# Response:  <Response [200]>
# Annual Summary 2019.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Annual Summary 2019.pdf
# Response:  <Response [200]>
# ANNUAL Summary 2017.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2017.pdf
# Response:  <Response [200]>
# ANNUAL Summary 2016 (Updated).pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2016 (Updated).pdf
# Response:  <Response [200]>
# ANNUAL Summary 2015.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2015.pdf
# Response:  <Response [200]>
# ANNUAL Summary 2014 (Corrected).pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2014 (Corrected).pdf
# Response:  <Response [200]>
# Annual Summary 2013.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Annual Summary 2013.pdf
# Response:  <Response [200]>
# summary12.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summary12.pdf
# Response:  <Response [200]>
# annualsummary2011.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/annualsummary2011.pdf
# Response:  <Response [200]>
# annual2010summary.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/annual2010summary.pdf
# Response:  <Response [200]>
# annualsummary2008.pdf downloaded to  c:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/annualsummary2008.pdf

# %% [markdown]
# ## Add data to DB

# %%
download_paths = [f.replace('\\', '/') for f in listdirs(os.getcwd()) if 'xlsx' in f and 'pmt' in f]
# print(download_paths)

with engine.connect() as connection:
    with connection.begin():
        result = connection.execute("create schema if not exists raw")
        result = connection.execute("drop table if exists raw.commodity")

# payments_df = pd.concat([pd.read_excel(f) for f in download_paths])
n = 0
for path in download_paths: 
    # if n > 3:
    #     break
    if '~' in path:
        continue
    print("Working on File {0} of {1}: {2}".format(n, len(download_paths), path))
    temp_df = pd.read_excel(path).rename(columns=lambda x: to_snake_case(x))
    print(temp_df.dtypes.to_markdown())
    if n > 0:
        curr_df = pd.read_sql("select * from raw.commodity limit 1", engine)
        fix_columns('raw.commodity', curr_df, temp_df, engine)
    temp_df.to_sql('commodity', engine, schema='raw', if_exists='append', index=False)
    n += 1

with engine.connect() as connection:
    with connection.begin():
        result = connection.execute("select * from raw.commodity limit 10")
        for row in result:
            print(row)

# %% [markdown]
# Added 63,822,217 rows.

# %%
with engine.connect() as connection:
    with connection.begin():
        connection.execute("""
            CREATE SCHEMA IF NOT EXISTS proc;
            
            DROP TABLE IF EXISTS proc.commodity;

            -- CREATE TABLE IF NOT EXISTS proc.commodity AS (
            --    SELECT lpad(state_fsa_code::text, 2, '0') || lpad(county_fsa_code::text, 2, '0') || accounting_program_code::text || lpad(row_number() over(order by payment_date asc, state_fsa_code asc, accounting_program_code asc)::text, 4, '0') as id, *
            --    FROM raw.commodity
            -- );

            CREATE TABLE IF NOT EXISTS proc.commodity AS (
                SELECT lpad(row_number() over(order by payment_date asc, state_fsa_code asc, county_fsa_code asc, accounting_program_code asc, accounting_program_year asc)::text, 12, '0') as id, *
                FROM raw.commodity
            );

            ALTER TABLE proc.commodity ADD PRIMARY KEY (id);
        """)

# %%
with engine.connect() as connection:
    with connection.begin():
        connection.execute("""
            CREATE SCHEMA IF NOT EXISTS proc;
            
            DROP TABLE IF EXISTS proc.commodity;

            -- CREATE TABLE IF NOT EXISTS proc.commodity AS (
            --    SELECT lpad(state_fsa_code::text, 2, '0') || lpad(county_fsa_code::text, 2, '0') || accounting_program_code::text || lpad(row_number() over(order by payment_date asc, state_fsa_code asc, accounting_program_code asc)::text, 4, '0') as id, *
            --    FROM raw.commodity
            -- );

            CREATE TABLE IF NOT EXISTS proc.commodity AS (
                SELECT lpad(row_number() over(order by payment_date asc, state_fsa_code asc, county_fsa_code asc, accounting_program_code asc, accounting_program_year asc)::text, 12, '0') as id, *
                FROM raw.commodity
            );

            ALTER TABLE proc.commodity ADD PRIMARY KEY (id);
        """)

# %%
exclusions_df = pd.read_csv('./data/raw/all_accounting_program_descriptions-jwc review.csv')
exclusions_df = exclusions_df.rename({'Include (Y or N)': 'include'}, axis='columns')
exclusions_df = exclusions_df.drop(columns=exclusions_df.columns[3])
exclusions_df.to_sql('crp_exclusions', engine, schema='raw', if_exists='replace', index=False)
exclusions_df
# Out:
#      accounting_program_code           accounting_program_description include
# 0                       1000                             MARKET GAINS       n
# 1                       1001                             MARKET GAINS       n
# 2                       1005                         STORAGE FORGIVEN       n
# 3                       1030                             MARKET GAINS       n
# 4                       2300                         INTEREST PENALTY       n
# ..                       ...                                      ...     ...
# 362                     8053            DAIRY MARGIN COVERAGE PROGRAM       y
# 363                     8055                    DMC PRGM-SUPPLEMENTAL       y
# 364                     8286  PANDEMIC ASST-TIMBER HARVESTERS/HAULERS       n
# 365                     8287     PANDEMIC LIVESTOCK INDEMNITY PROGRAM       n
# 366                     8292         SPOT MARKET HOG PANDEMIC PROGRAM       n
#
# [367 rows x 3 columns]

# %%
commodity_df = None
with engine.connect() as connection:
    with connection.begin():
        commodity_df = pd.read_sql(
            """
            select 
            trim(both from state_fsa_name),
            case 
                when extract(month from payment_date) >= 10 then extract(year from payment_date) + 1
                else extract(year from payment_date) end
                as fiscal_year,
            sum(disbursement_amount) as amount
            from proc.commodity
            where accounting_program_description not like '%%CRP%%'
            group by 1, 2
            order by 1 asc, 2 asc
            """,
            connection
        )
if not os.path.exists('./export/'):
        os.makedirs('./export/')
commodity_df.fiscal_year = commodity_df.fiscal_year.astype(np.int64)
for col, t in zip(commodity_df.columns, commodity_df.dtypes):
    if 'object' in str(t):
        commodity_df[col] = commodity_df[col].str.strip()
commodity_df.to_csv('./export/commodities.csv', index=False)
commodity_df
# Out:
#        btrim  fiscal_year        amount
# 0    Alabama         2005  6.982549e+05
# 1    Alabama         2006  6.194995e+05
# 2    Alabama         2007  2.361152e+05
# 3    Alabama         2008  5.741059e+07
# 4    Alabama         2009  1.041871e+08
# ..       ...          ...           ...
# 911  Wyoming         2018  1.983965e+07
# 912  Wyoming         2019  1.761115e+07
# 913  Wyoming         2020  9.514203e+07
# 914  Wyoming         2021  1.749209e+08
# 915  Wyoming         2022  2.354856e+07
#
# [916 rows x 3 columns]

# %%
commodity_by_program_df = None
with engine.connect() as connection:
    with connection.begin():
        commodity_by_program_df = pd.read_sql(
            """
            select 
            trim(both from state_fsa_name),
            case 
                when extract(month from payment_date) >= 10 then extract(year from payment_date) + 1
                else extract(year from payment_date) end
                as fiscal_year,
            accounting_program_code,
            accounting_program_description,
            sum(disbursement_amount) as amount
            from proc.commodity
            -- where accounting_program_description not like '%%CRP%%'
            group by 1, 2, 3, 4
            """,
            connection
        )
if not os.path.exists('./export/'):
        os.makedirs('./export/')
commodity_by_program_df.fiscal_year = commodity_by_program_df.fiscal_year.astype(np.int64)
for col, t in zip(commodity_by_program_df.columns, commodity_by_program_df.dtypes):
    if 'object' in str(t):
        commodity_by_program_df[col] = commodity_by_program_df[col].str.strip()
commodity_by_program_df.to_csv('./export/commodities_by_program.csv', index=False)
commodity_by_program_df
# Out:
#          btrim  fiscal_year  accounting_program_code  \
# 0      Alabama         2005                     2688
# 1      Alabama         2005                     5239
# 2      Alabama         2005                     5276
# 3      Alabama         2005                     5276
# 4      Alabama         2005                     5277
# ...        ...          ...                      ...
# 17194  Wyoming         2022                     6150
# 17195  Wyoming         2022                     6150
# 17196  Wyoming         2022                     6152
# 17197  Wyoming         2022                     8053
# 17198  Wyoming         2022                     8286
#
#                  accounting_program_description     amount
# 0               TRADE ADJUSTMENT - FISH, SHRIMP  115335.76
# 1             EWE LAMB REPLACEMENT OR RETENTION   87120.00
# 2      TOBACCO TRANSITION PYMNT-FLUE CURED,PROD  147165.10
# 3          TOBACCO TRANSITION PYMT-BURLEY, PROD    1791.00
# 4        TOBACCO TRANSITION PYMNT-BURLEY, QUOTA    3532.20
# ...                                         ...        ...
# 17194            CCC ORGANIC COST SHARE - CROPS    8089.05
# 17195        CCC ORGANIC COST SHARE - LIVESTOCK     400.00
# 17196    CCC ORGANIC COST SHARE FEES - HANDLING    2375.00
# 17197                     DAIRY MARGIN COVERAGE  149282.13
# 17198   PANDEMIC ASST-TIMBER HARVESTERS/HAULERS   78166.80
#
# [17199 rows x 5 columns]

# %%
filtered_commodities_df = None
with engine.connect() as connection:
    with connection.begin():
        filtered_commodities_df = pd.read_sql(
            """
            select 
            trim(both from state_fsa_name) as state,
            case 
                when extract(month from payment_date) >= 10 then extract(year from payment_date) + 1
                else extract(year from payment_date) end
                as fiscal_year,
            sum(disbursement_amount) as amount
            from proc.commodity
            where accounting_program_code not in (
                select accounting_program_code
                from raw.crp_exclusions
				where include = 'n'
            )
            group by 1, 2
            """,
            connection
        )
if not os.path.exists('./export/'):
        os.makedirs('./export/')
filtered_commodities_df.fiscal_year = filtered_commodities_df.fiscal_year.astype(np.int64)
for col, t in zip(filtered_commodities_df.columns, filtered_commodities_df.dtypes):
    if 'object' in str(t):
        filtered_commodities_df[col] = filtered_commodities_df[col].str.strip()
filtered_commodities_df.to_csv('./export/filtered_commodities.csv', index=False)
filtered_commodities_df
# Out:
#        state  fiscal_year       amount
# 0    Alabama         2005     87120.00
# 1    Alabama         2006    594112.49
# 2    Alabama         2007    234521.04
# 3    Alabama         2008  27004660.17
# 4    Alabama         2009  76467273.07
# ..       ...          ...          ...
# 910  Wyoming         2018  16518369.54
# 911  Wyoming         2019  12090270.08
# 912  Wyoming         2020  10060308.55
# 913  Wyoming         2021  52845839.20
# 914  Wyoming         2022  21669713.00
#
# [915 rows x 3 columns]

# %%
# filtered_commodities_df['amount'] = filtered_commodities_df['amount'].map('{:.2f}'.format)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
filtered_commodities_df[filtered_commodities_df['fiscal_year'] == 2021].sort_values('amount', ascending=False).head(10)
# Out:
#             state  fiscal_year       amount
# 786         Texas         2021 803051676.03
# 611  North Dakota         2021 508761946.32
# 287        Kansas         2021 466141292.86
# 413     Minnesota         2021 455197818.06
# 233      Illinois         2021 416934835.15
# 269          Iowa         2021 333155111.52
# 70       Arkansas         2021 331347636.25
# 750  South Dakota         2021 328523111.02
# 179       Georgia         2021 283968350.24
# 485      Nebraska         2021 275364269.35

# %%
filtered_commodities_by_program_df = None
with engine.connect() as connection:
    with connection.begin():
        filtered_commodities_by_program_df = pd.read_sql(
            """
            select 
            trim(both from state_fsa_name) as state,
            case 
                when extract(month from payment_date) >= 10 then extract(year from payment_date) + 1
                else extract(year from payment_date) end
                as fiscal_year,
            accounting_program_description,
            sum(disbursement_amount) as amount
            from proc.commodity
            where accounting_program_code not in (
                select accounting_program_code
                from raw.crp_exclusions
				where include = 'n'
            )
            group by 1, 2, 3
            """,
            connection
        )
if not os.path.exists('./export/'):
        os.makedirs('./export/')
filtered_commodities_by_program_df.fiscal_year = filtered_commodities_by_program_df.fiscal_year.astype(np.int64)
for col, t in zip(filtered_commodities_by_program_df.columns, filtered_commodities_by_program_df.dtypes):
    if 'object' in str(t):
        filtered_commodities_by_program_df[col] = filtered_commodities_by_program_df[col].str.strip()
filtered_commodities_by_program_df.to_csv('./export/filtered_commodities_by_program.csv', index=False)
filtered_commodities_by_program_df
# Out:
#         state  fiscal_year           accounting_program_description  \
# 0     Alabama         2005        EWE LAMB REPLACEMENT OR RETENTION
# 1     Alabama         2006               INCOME LOSS - MILK, PART 2
# 2     Alabama         2007               INCOME LOSS - MILK, PART 2
# 3     Alabama         2008      05 - 07 LIVESTOCK INDEMNITY PROGRAM
# 4     Alabama         2008         DIRECT AND COUNTER CYCLICAL PROG
# ...       ...          ...                                      ...
# 6506  Wyoming         2022                    DAIRY MARGIN COVERAGE
# 6507  Wyoming         2022  EMERG ASSIST LIVESTOCK BEES FISH (ELAP)
# 6508  Wyoming         2022                 LIVESTOCK FORAGE PROGRAM
# 6509  Wyoming         2022              LIVESTOCK INDEMNITY PROGRAM
# 6510  Wyoming         2022              PRICE LOSS COVERAGE PROGRAM
#
#            amount
# 0        87120.00
# 1       594112.49
# 2       234521.04
# 3        44561.00
# 4     26606324.00
# ...           ...
# 6506    149282.13
# 6507    501912.00
# 6508  17137018.10
# 6509     20329.00
# 6510   3794523.77
#
# [6511 rows x 4 columns]

# %%
filtered_commodities_df = commodity_by_program_df[
    commodity_by_program_df['accounting_program_code']\
        .isin(
            exclusions_df['accounting_program_code'][exclusions_df['include'] == 'y']
        )
].agg(
    {
        'amount': ['sum']
    }
)
filtered_commodities_df.to_csv('./export/filtered_commodities.csv', index=False)
filtered_commodities_df
# Out:
#          btrim  fiscal_year  accounting_program_code  \
# 1      Alabama         2005                     5239
# 7      Alabama         2006                     8020
# 9      Alabama         2007                     8020
# 11     Alabama         2008                     2521
# 16     Alabama         2008                     2714
# ...        ...          ...                      ...
# 17181  Wyoming         2022                     2835
# 17182  Wyoming         2022                     2837
# 17183  Wyoming         2022                     2838
# 17184  Wyoming         2022                     2840
# 17197  Wyoming         2022                     8053
#
#                  accounting_program_description       amount
# 1             EWE LAMB REPLACEMENT OR RETENTION     87120.00
# 7                    INCOME LOSS - MILK, PART 2    594112.49
# 9                    INCOME LOSS - MILK, PART 2    234521.04
# 11          05 - 07 LIVESTOCK INDEMNITY PROGRAM     44561.00
# 16             TREE ASSISTANCE PROGRAM - TIMBER    348449.00
# ...                                         ...          ...
# 17181                  LIVESTOCK FORAGE PROGRAM  17137018.10
# 17182               PRICE LOSS COVERAGE PROGRAM   3794523.77
# 17183  AGRICULTURAL RISK COVERAGE PROG - COUNTY     66526.00
# 17184   AGRICULTURAL RISK COVERAGE - INDIVIDUAL       122.00
# 17197                     DAIRY MARGIN COVERAGE    149282.13
#
# [6857 rows x 5 columns]

# %%
crp_df = None
with engine.connect() as connection:
    with connection.begin():
        exclusions_df = pd.read_sql(
            """
            select 
            trim(both from state_fsa_name),
            case 
                when extract(month from payment_date) >= 10 then extract(year from payment_date) + 1
                else extract(year from payment_date) end
                as fiscal_year,
            sum(disbursement_amount) as amount
            from proc.commodity
            where accounting_program_description like '%%CRP%%'
            group by 1, 2
            """,
            connection
        )
if not os.path.exists('./export/'):
        os.makedirs('./export/')
crp_df.fiscal_year = crp_df.fiscal_year.astype(np.int64)
for col, t in zip(crp_df.columns, crp_df.dtypes):
    if 'object' in str(t):
        crp_df[col] = crp_df[col].str.strip()
crp_df.to_csv('./export/commodity_crp_exclusions_by_year.csv', index=False)
crp_df
# Out:
#        btrim  fiscal_year       amount
# 0    Alabama         2008   1428966.82
# 1    Alabama         2009   1958473.93
# 2    Alabama         2010  21226392.86
# 3    Alabama         2011  20608921.82
# 4    Alabama         2012  17875501.69
# ..       ...          ...          ...
# 719  Wyoming         2018   5112312.00
# 720  Wyoming         2019   5105642.00
# 721  Wyoming         2020   5076702.00
# 722  Wyoming         2021   5032785.00
# 723  Wyoming         2022   3099081.94
#
# [724 rows x 3 columns]

# %% [markdown]
# ## Processing CRP Data

# %%
crp_file_list = find_file('.*conservation_summaries.*pdf')

crp_file_list
# Out:
# ['C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Annual Summary 2013.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2014 (Corrected).pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2015.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2016 (Updated).pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/ANNUAL Summary 2017.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Annual Summary 2019.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Annual Summary 2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/annual2010summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/annualsummary2008.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/annualsummary2011.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-nov-2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-oct-2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/DEC 2019 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/December 2018 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/January 2019 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/JULY 2018 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2018 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2022 Summary CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/MAY 2018 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/NOV 2019 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/November 2018 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT 2019 Summary2.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT2018 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Sep 2019 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2013summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2015summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/SEP2018 Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/September2017Summary.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 March.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 MAY.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary APR2020 (002).pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2019.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2019-1.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2020-1.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2021 CRP Monthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary FEB 2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2019.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JAN 2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2023 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2019-1.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUN 2019.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAR 2020.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary March 2021-1.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAY 2020-2.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary May 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary October 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary Octoberr 2022 CRPMonthly-1.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2021 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2022 CRPMonthly.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary-September-2020-1.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summary12.pdf',
#  'C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summarysept2014.pdf']

# %% [markdown]
# Setting up the processing function.

# %%
# pdf = "C:\\Users\\kwan1\\Documents\\GitHub\\IGPA\\data\\raw\\conservation_summaries\\summarysept2014.pdf"
pdf = crp_file_list[-1]

summary_titles = [
    "Total CRP (All Signups)",
    "General Signup",
    "Total Continuous",
    "CREP Only",
    "Continuous Non-CREP",
    "Farmable Wetland Program",
    "Grasslands Signup"
]

def pdf_to_dfs(pdf_dir: str, titles: list):
    """
    CRP enollroment tables starting from 2021 start on page 11 and then in 2022 start on page 12.

    Args:
        pdf_dir (str): _description_

    Returns:
        pd.DataFrame: _description_
    """
    pdf = pdf_dir.split('\\')[-1]
    # grasslands signup doesn't always appear on pg 15
    pages = '9-16'
    
    # 2021 and beyond
    if "202" in pdf:
        pages = '12-19'
    if "2020" in pdf:
        pages = '9-19'
    print("Working on \"{}\" pages {}".format(pdf, pages))
    raw_dfs = tabula.read_pdf(pdf_dir, pages=pages, stream=True, lattice=False)
    print("Extracted {} dataframes.".format(len(raw_dfs)))
    
    dfs = {}
    processed_n = 0
    titles.reverse()
    
    for df in raw_dfs:
        if len(df) < 10:
            # print("DF too short, moving on.")
            # display(df.head(3))
            continue
        # dfs[title] = process(df)
        try:
            processed = process(df)
            if any(processed) and len(titles) > 0:
                title = titles.pop()
                # print("Processed: {}".format(title))
                dfs[title] = process(df)
                processed_n += 1
        except Exception as e:
            print("Processed {} dataframes before error.".format(processed_n))
            # display(df.head(3))
            raise(e)
    print("Processed {} dataframes from {}.".format(processed_n, pdf))
    return dfs

def process(df):
    if filter_df(df):
        return pd.DataFrame()
    columns_1 = df.columns.str.replace(r"\.[0-9]|[0-9]\/", "", regex=True)
    columns_1 = columns_1.str.replace(r"Unnamed: [0-9]", "", regex=True).to_frame().T
    columns_2 = [" " + str(c) for c in df.iloc[0,:].str.replace(r"\.[0-9]|[0-9]\/", "", regex=True).values]
    # columns_2 = " " + df.iloc[0,:].str.replace(r"\.[0-9]|[0-9]\/", "", regex=True).values
    # display(columns_1, columns_2)
    columns = (columns_1 + columns_2).apply(lambda series: series.str.strip().str.lower()).T
    columns = columns.apply(lambda col: col[0], axis=1).T
    df.columns = columns
    # display(columns)
    df = df.drop(labels=[0])

    for col in df.columns:
        try:
            if pd.isna(col) or type(col) is not str:
                # print("Bad col type {}".format(type(col)))
                # display(df.columns)
                return pd.DataFrame()
        except Exception as e:
            print("Could not check column {} because of {}".format(col, e))
            # return pd.DataFrame()
            
    contains_payments = columns.str.contains("payments")
    if contains_payments.any():
        payment_col = columns[contains_payments]
        col_0 = "annual rental payments ($1,000)"
        col_1 = "annual rental payments ($/acre)"
        # this is still not splitting the numbers from the payment columns correctly
        # number_format = r"(([0-9]{1,3},)*[0-9]{1,3})([0-9]+\.[0-9]{2})"
        # currently working regex
        # this format is dependant on $/acre always being 4 or 5 digits
        number_format = r"(([0-9]{1,3})?((,?[0-9]{3})+|([0-9]{1,2})))([0-9]{2,3}\.[0-9]{2})"
        # display(df[payment_col.item()].str.extract(number_format, expand=True))
        new_cols = df[payment_col.item()].str.extract(number_format, expand=True).drop(columns=[1,2,3,4])
        new_cols = new_cols.rename(columns={new_cols.columns[0]: col_0, new_cols.columns[-1]: col_1})
        new_cols = new_cols.apply(lambda col: col.str.replace(r'^[.*]$', '0', regex=True))
        new_cols = new_cols.apply(lambda col: col.str.replace(r'.\*.', '0', regex=True))
        new_cols = new_cols.apply(lambda col: col.str.replace(',', '').astype(float))
        df = pd.concat([df.drop(columns=[payment_col.item()]), new_cols], axis="columns")
        
    for col in df.columns:
        if ("number" in col or "acres" in col) and ("$" not in col):
            try:
                df[col] = df[col].str.replace(r'^.*[.*].*$', '0', regex=True)
                df[col] = df[col].str.replace(',', '')
                # df[col] = df[col].astype("float64")
            except Exception as e:
                # print("Column {} could not be processed".format(col))
                # display(df.head(3))
                # raise(e)
                return pd.DataFrame()
    if filter_df(df):
        return pd.DataFrame()
    # display(df.head(1))
    return df

def filter_df(df):
    # print(df.columns.to_series().str.contains(".*20[0-9]{2}|agreement.*", case=False, regex=True))
    contains_bad_col = df.columns.to_series().str.contains(".*20[0-9]{2}|agree|plant.*", case=False, regex=True)
    if contains_bad_col.any():
        # print("Dataframe has irrelevant data, moving on.")
        # display(df.head(3))
        return True
    return False

def extract_date(path: str) -> date:
    try:
        file_name = path.split('/')[-1].replace('-', ' ')
        if '\\' in path:
            file_name = path.split('\\')[-1]
        file_name = re.sub(r'([a-z])\1+', r'\1', file_name.lower())
        file_name = file_name.replace("sumary", "summary")
        date_grouping = re.match(r"^([a-z]+[^a-z])?(annual)?(summary)?[^a-z]?([a-z]{3,10})?[^a-z]?([0-9]{4})([a-z -]{3,10})?", 
                                file_name.lower())
        # display(date_grouping.groups())
        month = date_grouping.group(4)
        if month is None or 'summary' in month:
            month = date_grouping.group(6).strip()
        if month is None or 'summary' in month:
            month = date_grouping.group(1).strip()
        year = date_grouping.group(5)
        if month is None or 'summary' in month: 
            return pd.to_datetime(year, format="%Y").date()
        else:
            return pd.to_datetime(str(month) + " " + str(year)).date()
    except Exception as e:
        print("Error extracting date:")
        display(date_grouping.groups())
        raise(e)
    
display(extract_date("summarysept2014.pdf"))

display(extract_date("Summary APR2020 (002).pdf"))

display(extract_date("Summary 2019 March.pdf"))

display(extract_date("DEC 2019 summary.pdf"))

display(extract_date(pdf))

# dfs = pdf_to_dfs("C:/Users/kwan1/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-oct-2020.pdf", 
#                 summary_titles.copy())

# for key in summary_titles:
#     print(key)
#     display(dfs[key].head(2))

# for df in pdf_to_dfs(pdf):
#     # display(df)
#     excel_file = ""
#     sheet = ""
#     df.to_excel(excel_file, sheet_name=sheet)
# Out:
# datetime.date(2014, 9, 1)
# datetime.date(2020, 4, 1)
# datetime.date(2019, 3, 1)
# datetime.date(2019, 12, 1)
# datetime.date(2014, 9, 1)

# %% [markdown]
# Processing all the files present in `crp_file_list`.
#
# Some notes about processed CRP files:
#
# - RHODE ISLAND has *'s for NOV 2020

# %%
dfs = None

for f in crp_file_list:
    # if summary_date
    if "annual" in f.lower():
        continue
    curr_dfs = pdf_to_dfs(f, summary_titles.copy())
    if dfs is None:
        dfs = curr_dfs
    else:
        # print("Accumulated Titles: {} \nCurrent titles: {}".format(dfs.keys(), curr_dfs.keys()))
        for title in dfs:
            # display(dfs[title], curr_dfs[title])
            # if curr_dfs[title] is not pd.DataFrame:
            #     raise Exception()
            if title not in curr_dfs:
                # print("Title {} missing from {}.".format(title, f))
                continue
            summary_date = extract_date(f)
            # print("Extracted date : {}".format(summary_date))
            if summary_date.year < 2018:
                print("Skipping {} : {}".format(f, title))
                continue
            # print("Working on date {}.".format(summary_date))
            try:
                curr_dfs[title]["date"] = summary_date
                curr_dfs[title]["original file"] = f.split('/')[-1]
                curr_dfs[title] = curr_dfs[title].reset_index(drop=True, allow_duplicates=True)
                if "date" in dfs[title].columns:
                    if summary_date in dfs[title]["date"]:
                        print("Date {} exists already".format(summary_date))
                joined = pd.concat([dfs[title], curr_dfs[title]], join="outer", ignore_index=True)
                joined.columns = joined.columns.to_series()\
                    .str.replace(r"([a-z] ?)+", r"\1", case=False, regex=True)\
                        .str.strip()
                dfs[title] = joined 
            except Exception as e:
                # display(dfs[title].head(3), curr_dfs[title].head(3))
                # display("Combined DF shape: {} Current DF shape: {}".format(dfs[title].shape, curr_dfs[title].shape))
                try:
                    curr_dfs[title] = pd.DataFrame({col: "Error" for col in dfs[title]})
                    curr_dfs[title]["date"] = summary_date
                except:
                    continue
                # display(dfs[title].isna().sum(), curr_dfs[title].isna().sum())
                # display(dfs[title].columns, curr_dfs[title].columns)
                # raise(e)

len(dfs)
# Out:
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-nov-2020.pdf" pages 9-19
# Extracted 12 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-nov-2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-oct-2020.pdf" pages 9-19
# Extracted 12 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/crp-summary-oct-2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/DEC 2019 Summary.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/DEC 2019 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/December 2018 Summary.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/December 2018 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/January 2019 Summary.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/January 2019 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/JULY 2018 Summary.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/JULY 2018 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2018 Summary.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2018 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2022 Summary CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/June 2022 Summary CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/MAY 2018 Summary.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/MAY 2018 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/NOV 2019 Summary.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/NOV 2019 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/November 2018 Summary.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/November 2018 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT 2019 Summary2.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT 2019 Summary2.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT2018 Summary.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/OCT2018 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Sep 2019 Summary.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Sep 2019 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2013summary.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2013summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2015summary.pdf" pages 9-16
# Extracted 10 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/sep2015summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/SEP2018 Summary.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/SEP2018 Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/September2017Summary.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/September2017Summary.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 March.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 March.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 MAY.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary 2019 MAY.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary APR2020 (002).pdf" pages 9-19
# Extracted 14 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary APR2020 (002).pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2019.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2019.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2021 CRPMonthly.pdf" pages 12-19
# Extracted 10 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary April 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2019-1.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2019-1.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2020-1.pdf" pages 9-19
# Extracted 11 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary AUG 2020-1.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2021 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary August 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2020.pdf" pages 9-19
# Extracted 11 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2021 CRP Monthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2021 CRP Monthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary December 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary FEB 2020.pdf" pages 9-19
# Extracted 14 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary FEB 2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2019.pdf" pages 9-16
# Extracted 9 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2019.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2021 CRPMonthly.pdf" pages 12-19
# Extracted 9 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary February 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JAN 2020.pdf" pages 9-19
# Extracted 14 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JAN 2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2021 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2023 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary January 2023 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2019-1.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2019-1.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2020.pdf" pages 9-19
# Extracted 11 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUL 2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2021 CRPMonthly.pdf" pages 12-19
# Extracted 10 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JULY 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUN 2019.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUN 2019.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2020.pdf" pages 9-19
# Extracted 13 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2021 CRPMonthly.pdf" pages 12-19
# Extracted 10 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary JUNE 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAR 2020.pdf" pages 9-19
# Extracted 14 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAR 2020.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary March 2021-1.pdf" pages 12-19
# Extracted 9 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary March 2021-1.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAY 2020-2.pdf" pages 9-19
# Extracted 14 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary MAY 2020-2.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary May 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary May 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2021 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary November 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary October 2021 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary October 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary Octoberr 2022 CRPMonthly-1.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary Octoberr 2022 CRPMonthly-1.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2021 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2021 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2022 CRPMonthly.pdf" pages 12-19
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary September 2022 CRPMonthly.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary-September-2020-1.pdf" pages 9-19
# Extracted 12 dataframes.
# Processed 7 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/Summary-September-2020-1.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summary12.pdf" pages 9-16
# Extracted 4 dataframes.
# Processed 0 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summary12.pdf.
# Working on "C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summarysept2014.pdf" pages 9-16
# Extracted 8 dataframes.
# Processed 6 dataframes from C:/Users/omni/Documents/GitHub/IGPA/data/raw/conservation_summaries/summarysept2014.pdf.
# 7

# %%
for key in dfs:
    dfs[key].to_excel("export/crp/CRP Summaries 2014-2023 {}.xlsx".format(key))

# %%
# with pd.ExcelWriter("CRP Summaries 2014-2023.xlsx", 
#                     mode="a", 
#                     if_sheet_exists="replace", 
#                     engine='openpyxl') as writer:  
#     for key in dfs:
#         dfs[key].to_excel(writer, sheetname=key)
#     writer.save()
